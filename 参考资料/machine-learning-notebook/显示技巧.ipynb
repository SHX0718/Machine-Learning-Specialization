# %% [markdown]
# # Jupyter Notebook 文字高亮示例
#
# ## 基本高亮方法
#
# - 默认高亮：<mark>这是使用mark标签的高亮文本</mark>
# - 自定义颜色：<span style="background-color: #ffcc00">黄色高亮文本</span>
# - 渐变色高亮：<span style="background: linear-gradient(90deg, #ff9a9e, #fad0c4); padding: 2px 5px;">渐变高亮效果</span>
# - 数学模式高亮：$\color{blue}{\text{蓝色高亮文本}}$
# - 键盘样式高亮：<kbd>键盘样式高亮文本</kbd>
#
# ## 带边框的高亮样式
#
# <span style="
#   background-color: #e6f7ff;
#   border: 1px solid #91d5ff;
#   border-radius: 4px;
#   padding: 2px 6px;
#   font-weight: bold;
# ">带边框的高亮文本</span>
#
# ## 多行高亮示例
#
# > <mark>这是高亮的引用文本</mark>
# >
# > 你可以使用高亮来强调重要内容
# >
# > <span style="background-color: #f6ffed; border-left: 3px solid #52c41a; padding: 5px 10px; display: block;">
# > 绿色背景高亮文本<br>
# > 带左侧边框效果
# > </span>
#
# ## 代码中的高亮
#
# ```python
# # 这是普通代码注释
# print("普通代码")
#
# # <mark>这是高亮的代码注释</mark>
# print("高亮注释的代码")

# %% [markdown]
# ## 实际效果演示
#
# 在 Jupyter Notebook 中，上述代码会渲染为：
#
# # Jupyter Notebook 文字高亮示例
#
# ## 基本高亮方法
#
# - 默认高亮：<mark>这是使用mark标签的高亮文本</mark>
# - 自定义颜色：<span style="background-color: #ffcc00">黄色高亮文本</span>
# - 渐变色高亮：<span style="background: linear-gradient(90deg, #ff9a9e, #fad0c4); padding: 2px 5px;">渐变高亮效果</span>
# - 数学模式高亮：$\color{blue}{\text{蓝色高亮文本}}$
# - 键盘样式高亮：<kbd>键盘样式高亮文本</kbd>
#
# ## 带边框的高亮样式
#
# <span style="
#   background-color: #e6f7ff;
#   border: 1px solid #91d5ff;
#   border-radius: 4px;
#   padding: 2px 6px;
#   font-weight: bold;
# ">带边框的高亮文本</span>
#
# ## 多行高亮示例
#
# > <mark>这是高亮的引用文本</mark>
# >
# > 你可以使用高亮来强调重要内容
# >
# > <span style="background-color: #f6ffed; border-left: 3px solid #52c41a; padding: 5px 10px; display: block;">
# > 绿色背景高亮文本<br>
# > 带左侧边框效果
# > </span>
#
# ## 高级技巧：悬停效果
#
# <span style="
#   background-color: #f0f0f0;
#   padding: 3px 8px;
#   border-radius: 3px;
#   transition: all 0.3s;
#   display: inline-block;
# ">鼠标悬停查看效果</span>
#
# <style>
# span:hover {
#   background-color: #ffccc7 !important;
#   transform: scale(1.05);
#   box-shadow: 0 2px 8px rgba(0,0,0,0.1);
# }
# </style>
#
# ## 使用建议
#
# 1. **简单高亮**：使用 `<mark>` 标签最方便
# 2. **自定义颜色**：使用内联 CSS 样式
# 3. **数学公式**：在 LaTeX 环境中使用 `\color{}` 命令
# 4. **代码注释**：在代码单元格中使用 HTML 注释高亮
# 5. **交互效果**：添加 CSS 悬停效果增强用户体验
#
# 注意：在 Jupyter Notebook 中，所有 HTML 和 CSS 代码都需要放在 Markdown 单元格中才能正确渲染。
